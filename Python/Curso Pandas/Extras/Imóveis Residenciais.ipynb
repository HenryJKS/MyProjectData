# %% [markdown]
# # Relatório de Análise III

# %% [markdown]
# ## Imóveis Residenciais

# %%
import pandas as pd

# %%
dados = pd.read_csv('Datas/aluguel.csv', sep = ';')
pd.set_option('display.max_rows',100) # Para alterar quantidade de linhas
pd.set_option('display.max_columns',100) # Para alterar quantidade de linhas

# %%
dados.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento                   Centro        1      0       0    15   800.0
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU  Valor m2 Tipo Agregado
# 0       390.0   20.0     53.33   Apartamento
# ...

# %%
list(dados['Tipo'].drop_duplicates())
# Out:
# ['Apartamento', 'Casa', 'Casa de Condomínio', 'Casa de Vila', 'Quitinete']

# %%
residencial = ['Apartamento', 'Casa', 'Casa de Condomínio', 'Casa de Vila', 'Quitinete']

# %%
residencial
# Out:
# ['Apartamento', 'Casa', 'Casa de Condomínio', 'Casa de Vila', 'Quitinete']

# %%
dados.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento                   Centro        1      0       0    15   800.0
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU  Valor m2 Tipo Agregado
# 0       390.0   20.0     53.33   Apartamento
# ...

# %%
#Comparar a estrutura Residencial com a estrutura Tipo
selecao = dados['Tipo'].isin(residencial).head(10)
selecao
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: Tipo, dtype: bool

# %%
dados_residencial = dados[selecao]
# Out:
# C:\Users\Henry\AppData\Local\Temp\ipykernel_14952\2638623987.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dados_residencial = dados[selecao]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 dados_residencial = dados[selecao]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3796, in DataFrame.__getitem__(self, key)
#    3794 # Do we have a (boolean) 1d indexer?
#    3795 if com.is_bool_indexer(key):
# -> 3796     return self._getitem_bool_array(key)
#    3798 # We are left with two options: a single key, and a collection of keys,
#    3799 # We interpret tuples as collections only for non-MultiIndex
#    3800 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3849, in DataFrame._getitem_bool_array(self, key)
# ...
