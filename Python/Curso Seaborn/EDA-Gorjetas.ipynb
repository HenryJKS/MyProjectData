# %% [markdown]
# # Importando base de dados

# %%
import pandas as pd

# %%
dados = pd.read_csv('Datas/tips.csv', sep=',')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
dados.head(10)
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4
# 5       25.29  4.71      No  Sun  Dinner     4
# 6        8.77  2.00      No  Sun  Dinner     2
# 7       26.88  3.12      No  Sun  Dinner     4
# 8       15.04  1.96      No  Sun  Dinner     2
# 9       14.78  3.23      No  Sun  Dinner     2

# %% [markdown]
# ## Renomeando Colunas

# %% [markdown]
# ### Renomeando valores da Coluna 'sobremesa'

# %%
dados.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renomar = {
    'total_bill' : 'valor_da_conta', 
    'tip' : 'gorjeta', 
    'dessert' : 'sobremesa', 
    'day' : 'dia_da_semana', 
    'time' : 'hora_do_dia', 
    'size' : 'total_de_pessoas'
}

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
#Renomeando as Colunas com o dict Renomear
gorjetas = dados.rename(columns = renomar)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
#Vendo os unicos valores de uma coluna
gorjetas.sobremesa.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
#Criando uma dict para renomar a Coluna 'Sobremesa'
sim_nao = {
    'No' : 'Não',
    'Yes' : 'Sim'
}

# %%
#Mapeando para visualizar se foi feito a renomeação, nesse caso o DataFrame gorjeta ainda não recebeu a alteração
gorjetas.sobremesa.map(sim_nao)
# Out:
# 0      Não
# 1      Não
# 2      Não
# 3      Não
# 4      Não
# 5      Não
# 6      Não
# 7      Não
# 8      Não
# 9      Não
# 10     Não
# 11     Não
# 12     Não
# 13     Não
# 14     Não
# 15     Não
# 16     Não
# 17     Não
# 18     Não
# 19     Não
# 20     Não
# 21     Não
# 22     Não
# 23     Não
# 24     Não
# 25     Não
# 26     Não
# 27     Não
# 28     Não
# 29     Não
# 30     Não
# 31     Não
# 32     Não
# 33     Não
# 34     Não
# 35     Não
# 36     Não
# 37     Não
# 38     Não
# 39     Não
# 40     Não
# 41     Não
# 42     Não
# 43     Não
# 44     Não
# 45     Não
# 46     Não
# 47     Não
# 48     Não
# 49     Não
# 50     Não
# 51     Não
# 52     Não
# 53     Não
# 54     Não
# 55     Não
# 56     Sim
# 57     Não
# 58     Sim
# 59     Não
# 60     Sim
# 61     Sim
# 62     Sim
# 63     Sim
# 64     Não
# 65     Não
# 66     Não
# 67     Sim
# 68     Não
# 69     Sim
# 70     Não
# 71     Não
# 72     Sim
# 73     Sim
# 74     Não
# 75     Não
# ...

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
#Inserindo a renomeação
gorjetas.sobremesa = gorjetas.sobremesa.map(sim_nao)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não           Sun      Dinner
#
#    total_de_pessoas
# 0                 2

# %% [markdown]
# ### Renomeando valores da Coluna 'dia_da_semana'

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dia_semana = {
    'Sun' : 'Domingo',
    'Sat' : 'Sábado',
    'Thur' : 'Quinta',
    'Fri' : 'Sexta'
}

# %%
gorjetas.dia_da_semana.map(dia_semana)
# Out:
# 0      Domingo
# 1      Domingo
# 2      Domingo
# 3      Domingo
# 4      Domingo
# 5      Domingo
# 6      Domingo
# 7      Domingo
# 8      Domingo
# 9      Domingo
# 10     Domingo
# 11     Domingo
# 12     Domingo
# 13     Domingo
# 14     Domingo
# 15     Domingo
# 16     Domingo
# 17     Domingo
# 18     Domingo
# 19      Sábado
# 20      Sábado
# 21      Sábado
# 22      Sábado
# 23      Sábado
# 24      Sábado
# 25      Sábado
# 26      Sábado
# 27      Sábado
# 28      Sábado
# 29      Sábado
# 30      Sábado
# 31      Sábado
# 32      Sábado
# 33      Sábado
# 34      Sábado
# 35      Sábado
# 36      Sábado
# 37      Sábado
# 38      Sábado
# 39      Sábado
# 40      Sábado
# 41     Domingo
# 42     Domingo
# 43     Domingo
# 44     Domingo
# 45     Domingo
# 46     Domingo
# 47     Domingo
# 48     Domingo
# 49     Domingo
# 50     Domingo
# 51     Domingo
# 52     Domingo
# 53     Domingo
# 54     Domingo
# 55     Domingo
# 56      Sábado
# 57      Sábado
# ...

# %%
gorjetas.dia_da_semana = gorjetas.dia_da_semana.map(dia_semana)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Dinner
#
#    total_de_pessoas
# 0                 2

# %% [markdown]
# ### Renomando os valores da Coluna 'hora_do_dia'

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
almoco_janta = {
    'Dinner' : 'Jantar',
    'Lunch' : 'Almoco'
}

# %%
gorjetas.hora_do_dia.map(almoco_janta).head(1)
# Out:
# 0    Jantar
# Name: hora_do_dia, dtype: object

# %%
gorjetas.hora_do_dia = gorjetas.hora_do_dia.map(almoco_janta)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2

# %% [markdown]
# # Importando o Seaborn

# %%
import seaborn as sns

# %% [markdown]
# ## Análise I - Valor da conta e gorjeta

# %%
gorjetas.columns
# Out:
# Index(['valor_da_conta', 'gorjeta', 'sobremesa', 'dia_da_semana',
#        'hora_do_dia', 'total_de_pessoas'],
#       dtype='object')

# %%
#Gerando gráfico
valor_gorjeta = sns.scatterplot(x = 'valor_da_conta', y = 'gorjeta', data = gorjetas)

# %% [markdown]
# ### **Visualmente o valor da gorjeta aumenta conforme aumenta o valor da conta**

# %%
#Verificar registros
print(f'A base de dados contém {gorjetas.shape[0]} registros')
# Out:
# A base de dados contém 244 registros

# %%
#Verificar registro nulos
print(f'Verificar registro nulos')
gorjetas.count()
# Out:
# Verificar registro nulos
# valor_da_conta      244
# gorjeta             244
# sobremesa           244
# dia_da_semana       244
# hora_do_dia         244
# total_de_pessoas    244
# dtype: int64

# %% [markdown]
# ## Criando o campo 'porcentagem'

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2

# %%
#Criando um novo campo
gorjetas['porcentagem'] = (gorjetas['gorjeta'] / gorjetas['valor_da_conta']).round(2)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06

# %%
porcentagem_conta = sns.scatterplot(x = 'valor_da_conta', y = 'porcentagem', data = gorjetas)

# %% [markdown]
# ### **Visualmente, o valor_da_conta não é proporcional ao valor da gorjeta**

# %% [markdown]
# # Gerando outros gráficos

# %%
porcentagem_conta_linha = sns.relplot(x = 'valor_da_conta', y = 'porcentagem', kind = 'line', data = gorjetas)

# %%
sns.lmplot(x = 'valor_da_conta', y = 'porcentagem', data = gorjetas)

# %% [markdown]
# # Análise II - Sobremesa

# %%
#Verificar todos aqueles que pediram sobremesa
gorjetas[gorjetas.sobremesa == 'Sim'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       93.000000  93.000000         93.000000    93.000000
# mean        20.756344   3.008710          2.408602     0.163226
# std          9.832154   1.401468          0.810751     0.085060
# min          3.070000   1.000000          1.000000     0.040000
# 25%         13.420000   2.000000          2.000000     0.110000
# 50%         17.920000   3.000000          2.000000     0.150000
# 75%         26.860000   3.680000          3.000000     0.200000
# max         50.810000  10.000000          5.000000     0.710000

# %%
#Verificar todos aqueles que não pediram sobremesa
gorjetas[gorjetas.sobremesa == 'Não'].describe()
# Out:
#        valor_da_conta     gorjeta  total_de_pessoas  porcentagem
# count      151.000000  151.000000        151.000000   151.000000
# mean        19.188278    2.991854          2.668874     0.159536
# std          8.255582    1.377190          1.017984     0.039889
# min          7.250000    1.000000          1.000000     0.060000
# 25%         13.325000    2.000000          2.000000     0.140000
# 50%         17.590000    2.740000          2.000000     0.160000
# 75%         22.755000    3.505000          3.000000     0.185000
# max         48.330000    9.000000          6.000000     0.290000

# %%
sns.catplot(x = 'sobremesa', y = 'gorjeta', data = gorjetas)

# %%
sns.relplot(x = 'valor_da_conta', y = 'gorjeta', hue = 'sobremesa', data = gorjetas)

# %%
sns.relplot(x = 'valor_da_conta', y = 'gorjeta', hue = 'sobremesa', col='sobremesa', data = gorjetas)

# %%
sns.lmplot(x = 'valor_da_conta', y = 'porcentagem', col = 'sobremesa', hue = 'sobremesa', data = gorjetas)

# %%
sns.relplot(x = 'valor_da_conta', y = 'porcentagem', hue = 'sobremesa', col='sobremesa', kind = 'line', data = gorjetas)

# %% [markdown]
# ### **Visualmente existe uma diferença no valor da gorjeta, daqueles que pediram sobremesa e não pediram sobremesa**

# %% [markdown]
# # Teste de Hipótese

# %% [markdown]
# ## **H<sup>null</sup>**
# ### **A distribuição da taxa de gorjeta é a mesma nos dois grupos**
#
# ## **H<sup>alt</sup>**
# ### **A distribuição da taxa de gorjeta não é a mesma nos dois grupos**

# %%
from scipy.stats import ranksums

# %%
sobremesa = gorjetas.query("sobremesa == 'Sim'").porcentagem

# %%
sem_sobremesa = gorjetas.query("sobremesa == 'Não'").porcentagem

# %%
r = ranksums(sobremesa, sem_sobremesa)

# %%
print(f'O valor do p-value é {r.pvalue}')
# Out:
# O valor do p-value é 0.5266635660124415

# %% [markdown]
# ## Hipotese que aceitamos
# ## **H<sup>null</sup>**
# ### **A distribuição da taxa de gorjeta é a mesma nos dois grupos**

# %% [markdown]
# # Análise III - Dia da Semana

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sábado', 'Quinta', 'Sexta'], dtype=object)

# %%
sns.catplot(x = 'dia_da_semana', y = 'valor_da_conta', data = gorjetas)

# %%
sns.relplot(x = 'valor_da_conta', y = 'gorjeta', hue = 'dia_da_semana', data = gorjetas)

# %%
sns.relplot(x = 'valor_da_conta', y = 'porcentagem', hue = 'dia_da_semana', data = gorjetas)

# %%
x = sns.relplot(x = 'valor_da_conta', y = 'gorjeta', hue = 'dia_da_semana', col = 'dia_da_semana', data = gorjetas)
x.figure.set_size_inches(15, 5)

# %%
y = sns.relplot(x = 'valor_da_conta', y = 'porcentagem', hue = 'dia_da_semana', col = 'dia_da_semana', data = gorjetas)
y.figure.set_size_inches(15, 5)

# %%
z = sns.lmplot(x = 'valor_da_conta', y = 'porcentagem', hue = 'dia_da_semana', col = 'dia_da_semana', data = gorjetas)
z.figure.set_size_inches(15, 5)

# %%
media_geral_gorjetas = gorjetas.gorjeta.mean().round(2)
print(f'A média geral das gorjetas é de {media_geral_gorjetas}')
# Out:
# A média geral das gorjetas é de 3.0

# %%
#Fazendo um group by de cada dia da semana, e fazendo a média de cada uma delas
agrupando_dia_da_semana = gorjetas.groupby(['dia_da_semana']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
agrupando_dia_da_semana
# Out:
# C:\Users\Henry\AppData\Local\Temp\ipykernel_20396\2886945092.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   agrupando_dia_da_semana = gorjetas.groupby(['dia_da_semana']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
#                valor_da_conta   gorjeta  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132     0.166974
# Quinta              17.682742  2.771452     0.161129
# Sexta               17.151579  2.734737     0.169474
# Sábado              20.441379  2.993103     0.153678

# %%
#Conta a frequência de cada dia
print('Frequência dos dias')
gorjetas.dia_da_semana.value_counts()
# Out:
# Frequência dos dias
# Sábado     87
# Domingo    76
# Quinta     62
# Sexta      19
# Name: dia_da_semana, dtype: int64

# %% [markdown]
# ## Teste de Hipotese

# %% [markdown]
# ### **H<sup>null</sup>**
# ### **A distribuição do valor da conta é igual no sábado e no domingo**
#
# ### **H<sup>alt</sup>**
# ### **A distribuição do valor da conta não é igual no sábado e no domingo**

# %%
valor_conta_domingo = gorjetas.query("dia_da_semana == 'Domingo'").valor_da_conta

# %%
valor_conta_sabado = gorjetas.query("dia_da_semana == 'Sábado'").valor_da_conta

# %%
#Caso o numero do pvalue for <= 0.05 podemos aceitar a Hipotese Alternativa
r2 = ranksums(valor_conta_domingo, valor_conta_sabado)
print(f"O valor do pvalue é {r2.pvalue}")
# Out:
# O valor do pvalue é 0.3576728477868443

# %% [markdown]
# ## Hipotese que aceitamos
# ### **H<sup>null</sup>**
# ### **A distribuição do valor da conta é igual no sábado e no domingo**

# %% [markdown]
# # Análise IV - Hora do Dia

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Jantar', 'Almoco'], dtype=object)

# %%
sns.catplot(x = 'hora_do_dia', y = 'valor_da_conta', hue = 'hora_do_dia', data = gorjetas)

# %% [markdown]
# ### **Visualizando nota-se que, o Jantar os valores da conta são maiores comparado com Almoço**

# %%
sns.catplot(x = 'hora_do_dia', y = 'valor_da_conta', hue = 'hora_do_dia', kind = 'swarm', data = gorjetas)

# %%
sns.violinplot(x = 'hora_do_dia', y = 'valor_da_conta', data = gorjetas)
# Out:
# <Axes: xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
sns.boxplot(x = 'hora_do_dia', y = 'valor_da_conta', data = gorjetas)
# Out:
# <Axes: xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
almoco = gorjetas.query("hora_do_dia == 'Almoco'").valor_da_conta

# %%
jantar = gorjetas.query("hora_do_dia == 'Jantar'").valor_da_conta

# %%
sns.displot(almoco, kde = False)
sns.displot(jantar, kde = False)

# %%
gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
# C:\Users\Henry\AppData\Local\Temp\ipykernel_20396\932548386.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
#              valor_da_conta   gorjeta  porcentagem
# hora_do_dia
# Almoco            17.168676  2.728088     0.163971
# Jantar            20.797159  3.102670     0.159773

# %% [markdown]
# ## Teste de Hipotese

# %% [markdown]
# ### **H<sup>null</sup>**
# ### **A distribuição do valor da conta é igual no almoço e da janta**
#
# ### **H<sup>alt</sup>**
# ### **A distribuição do valor da conta nãoe é igual no almoço e da janta**

# %%
r2 = ranksums(almoco, jantar)
print(f"O pvalue é {r2.pvalue}")
# Out:
# O pvalue é 0.0011791039723641672

# %% [markdown]
# ## Hipotese aceita
# ### **H<sup>alt</sup>**
# ### **A distribuição do valor da conta nãoe é igual no almoço e da janta**

# %% [markdown]
# # Teste de Hipotese II

# %% [markdown]
# ## Teste de Hipotese

# %% [markdown]
# ### **H<sup>null</sup>**
# ### **A distribuição da taxa da gorjeta é igual no almoço e da janta**
#
# ### **H<sup>alt</sup>**
# ### **A distribuição da taxa da gorjeta não é igual no almoço e da janta**

# %%
almoco_porcentagem = gorjetas.query("hora_do_dia == 'Almoco'").porcentagem

# %%
janta_porcentagem = gorjetas.query("hora_do_dia == 'Jantar'").porcentagem

# %%
r3 = ranksums(almoco_porcentagem, janta_porcentagem)
print(f"O pvalue é {r3.pvalue}")
# Out:
# O pvalue é 0.2602493995587126

# %% [markdown]
# ## Hipotese aceita
# ### **H<sup>null</sup>**
# ### **A distribuição da taxa da gorjeta é igual no almoço e da janta**
