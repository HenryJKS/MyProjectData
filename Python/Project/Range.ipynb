# %%
import pandas as pd
import re

# %%
dataExpress = pd.read_excel('./Datas/Express.xlsx')
dataStandard = pd.read_excel('./Datas/Standart.xlsx')
dataShipments = pd.read_csv('./Datas/Shipments2.csv')

# %%
dataShipments = dataShipments.rename(columns = {'to_postcode' : 'CEPS'})

# %%
eliminar = r'\D'

# %%
dataShipments['CEPS'] = dataShipments['CEPS'].apply(lambda x: re.sub(eliminar, '', x))

# %%
dataShipments
# Out:
#            CEPS  to_country_id
# 0      00000000             32
# 1      00005820             32
# 2      01031970             32
# 3      01033001             64
# 4      01033001             32
# ...         ...            ...
# 15934  99940000             32
# 15935  99950000            128
# 15936  99950000             64
# 15937     33308            236
# 15938                       32
#
# [15939 rows x 2 columns]

# %%
dataShipments.head()
# Out:
#        CEPS  to_country_id
# 0  00000000             32
# 1  00005820             32
# 2  01031970             32
# 3  01033001             64
# 4  01033001             32

# %%
#Filtrando apenas pelo Country_id 32 (Brasil)
dataShipments_filtro = dataShipments.loc[dataShipments['to_country_id'] == 32]

# %%
dataShipments_filtro.head()
# Out:
#        CEPS  to_country_id
# 0  00000000             32
# 1  00005820             32
# 2  01031970             32
# 4  01033001             32
# 7  01041000             32

# %%
dataShipments_filtro
# Out:
#            CEPS  to_country_id
# 0      00000000             32
# 1      00005820             32
# 2      01031970             32
# 4      01033001             32
# 7      01041000             32
# ...         ...            ...
# 15929  99830000             32
# 15931  99870000             32
# 15932  99870000             32
# 15934  99940000             32
# 15938                       32
#
# [11506 rows x 2 columns]

# %% [markdown]
# # Calculando Range

# %%
dataExpress.head()
# Out:
#     CEP INI   CEP FIN    NOME COBERTURA  UF FRANQUIA  EXPRESSO
# 0  16800000  16849999      MIRANDOPOLIS  SP      AAN  ATENDIDO
# 1  16900001  16905265         ANDRADINA  SP      AAN  ATENDIDO
# 2  16920000  16939999          CASTILHO  SP      AAN  ATENDIDO
# 3  16950000  16979999  MURUTINGA DO SUL  SP      AAN  ATENDIDO
# 4  16980000  16999999          GUARACAI  SP      AAN  ATENDIDO

# %%
len(dataExpress)
# Out:
# 2691

# %%
len(dataShipments)
# Out:
# 15939

# %%
dataExpress.head()
# Out:
#     CEP INI   CEP FIN    NOME COBERTURA  UF FRANQUIA  EXPRESSO
# 0  16800000  16849999      MIRANDOPOLIS  SP      AAN  ATENDIDO
# 1  16900001  16905265         ANDRADINA  SP      AAN  ATENDIDO
# 2  16920000  16939999          CASTILHO  SP      AAN  ATENDIDO
# 3  16950000  16979999  MURUTINGA DO SUL  SP      AAN  ATENDIDO
# 4  16980000  16999999          GUARACAI  SP      AAN  ATENDIDO

# %%
dataExpress = dataExpress.rename(columns = {'CEP INI' : 'CEP_INI'})
dataExpress = dataExpress.rename(columns = {'CEP FIN' : 'CEP_FINAL'})
dataExpress
# Out:
#        CEP_INI  CEP_FINAL    NOME COBERTURA  UF FRANQUIA  EXPRESSO
# 0     16800000   16849999      MIRANDOPOLIS  SP      AAN  ATENDIDO
# 1     16900001   16905265         ANDRADINA  SP      AAN  ATENDIDO
# 2     16920000   16939999          CASTILHO  SP      AAN  ATENDIDO
# 3     16950000   16979999  MURUTINGA DO SUL  SP      AAN  ATENDIDO
# 4     16980000   16999999          GUARACAI  SP      AAN  ATENDIDO
# ...        ...        ...               ...  ..      ...       ...
# 2686  82720000   82729999          CURITIBA  PR      ZUT  ATENDIDO
# 2687  82800000   82849999          CURITIBA  PR      ZUT  ATENDIDO
# 2688  82860000   82869999          CURITIBA  PR      ZUT  ATENDIDO
# 2689  82900000   82909999          CURITIBA  PR      ZUT  ATENDIDO
# 2690  82920000   82999999          CURITIBA  PR      ZUT  ATENDIDO
#
# [2691 rows x 6 columns]

# %%
dataShipments.head()
# Out:
#        CEPS  to_country_id
# 0  00000000             32
# 1  00005820             32
# 2  01031970             32
# 3  01033001             64
# 4  01033001             32

# %%
def range1(cep_verifica, cep_inicial, cep_final):
    return int(cep_inicial) <= int(cep) <= int(cep_final)

# %%
cep_range = 0
total_ceps = len(dataShipments)

# %%
dataShipments
# Out:
#            CEPS  to_country_id
# 0      00000000             32
# 1      00005820             32
# 2      01031970             32
# 3      01033001             64
# 4      01033001             32
# ...         ...            ...
# 15934  99940000             32
# 15935  99950000            128
# 15936  99950000             64
# 15937     33308            236
# 15938                       32
#
# [15939 rows x 2 columns]

# %%
dataShipments.dtypes
# Out:
# CEPS             object
# to_country_id     int64
# dtype: object

# %%
dataShipments
# Out:
#            CEPS  to_country_id
# 0      00000000             32
# 1      00005820             32
# 2      01031970             32
# 3      01033001             64
# 4      01033001             32
# ...         ...            ...
# 15934  99940000             32
# 15935  99950000            128
# 15936  99950000             64
# 15937     33308            236
# 15938                       32
#
# [15939 rows x 2 columns]

# %%
for index, row in dataExpress.iterrows():
    cep_inicial = row['CEP_INI']
    cep_final = row['CEP_FINAL']

for index, row in dataShipments.iterrows():
    cep = row['CEPS']
    
    if cep_inicial != '' and cep_final != '':
        cep_inicial = int(cep_inicial)
        cep_final = int(cep_final)
            
    ceps = dataShipments['CEPS'].apply(lambda cep: cep_inicial <= cep <= cep_final).sum()

    if ceps > 0:
        cep_range += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 12
#       9     cep_inicial = int(cep_inicial)
#      10     cep_final = int(cep_final)
# ---> 12 ceps = dataShipments['CEPS'].apply(lambda cep: cep_inicial <= cep <= cep_final).sum()
#      14 if ceps > 0:
#      15     cep_range += 1
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1105, in SeriesApply.apply(self)
# ...

# %%
porcentagem = (cep_range / len(dataShipments)) * 100

# %%
print(porcentagem)
