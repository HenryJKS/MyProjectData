# %%
import pandas as pd
import re
import numpy as np

# %%
data_express = pd.read_excel('./Datas/Express.xlsx')
data_standard = pd.read_excel('./Datas/Standart.xlsx')
data_shipments = pd.read_csv('./Datas/Shipments2.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data_shipments = data_shipments.rename(columns = {"to_postcode" : "CEP"})

# %%
data_shipments.head()
# Out:
#          CEP  to_country_id
# 0   00000000             32
# 1  00005-820             32
# 2  01031-970             32
# 3   01033001             64
# 4  01033-001             32

# %%
data_shipments['CEP'] =  data_shipments['CEP'].replace(to_replace=r'\D+', value='', regex=True)

# %%
data_shipments.head()
# Out:
#         CEP  to_country_id
# 0  00000000             32
# 1  00005820             32
# 2  01031970             32
# 3  01033001             64
# 4  01033001             32

# %%
data_shipments = data_shipments.loc[data_shipments['to_country_id'] == 32]

# %%
data_shipments.dtypes
# Out:
# CEP              object
# to_country_id     int64
# dtype: object

# %%
data_shipments = data_shipments.reset_index(drop = True)

# %%
valor_vazio = 1

# %%
data_shipments['CEP'] = data_shipments['CEP'].str.strip()

# %%
data_shipments['CEP'] = data_shipments['CEP'].replace('', np.nan)

# %%
 data_shipments = data_shipments.fillna(valor_vazio)

# %%
data_shipments
# Out:
#             CEP  to_country_id
# 0      00000000             32
# 1      00005820             32
# 2      01031970             32
# 3      01033001             32
# 4      01041000             32
# 5      01046925             32
# 6      01047020             32
# 7      01050020             32
# 8      01050030             32
# 9      01105010             32
# 10     01121000             32
# 11     01122030             32
# 12     01124010             32
# 13     01131000             32
# 14     01131010             32
# 15     01132010             32
# 16     01132010             32
# 17     01136010             32
# 18     01141000             32
# 19     01153000             32
# 20     01155040             32
# 21     01207001             32
# 22     01214100             32
# 23     01215010             32
# 24     01215010             32
# 25     01217000             32
# 26     01217011             32
# 27     01220010             32
# 28     01222000             32
# ...

# %%
data_standard.head()
# Out:
#     CEP INI   CEP FIN    NOME COBERTURA  UF FRANQUIA  STANDARD
# 0  16800000  16849999      MIRANDOPOLIS  SP      AAN  ATENDIDO
# 1  16900001  16905265         ANDRADINA  SP      AAN  ATENDIDO
# 2  16920000  16939999          CASTILHO  SP      AAN  ATENDIDO
# 3  16950000  16979999  MURUTINGA DO SUL  SP      AAN  ATENDIDO
# 4  16980000  16999999          GUARACAI  SP      AAN  ATENDIDO

# %%
data_standard = data_standard.rename(columns = {'CEP INI' : 'CEP_INI'})
data_standard = data_standard.rename(columns = {'CEP FIN' : 'CEP_FIN'})

# %%
data_standard.head()
# Out:
#     CEP_INI   CEP_FIN    NOME COBERTURA  UF FRANQUIA  STANDARD
# 0  16800000  16849999      MIRANDOPOLIS  SP      AAN  ATENDIDO
# 1  16900001  16905265         ANDRADINA  SP      AAN  ATENDIDO
# 2  16920000  16939999          CASTILHO  SP      AAN  ATENDIDO
# 3  16950000  16979999  MURUTINGA DO SUL  SP      AAN  ATENDIDO
# 4  16980000  16999999          GUARACAI  SP      AAN  ATENDIDO

# %%
data_standard.dtypes
# Out:
# CEP_INI            int64
# CEP_FIN            int64
# NOME COBERTURA    object
# UF                object
# FRANQUIA          object
# STANDARD          object
# dtype: object

# %%
#data_standard['CEP_INI'] = data_standard['CEP_INI'].astype(str)
#data_standard['CEP_FIN'] = data_standard['CEP_FIN'].astype(str)

# %%
data_standard['CEP_RANGE'] = [list(range(cep_ini, cep_fin + 1)) for cep_ini, cep_fin in zip(data_standard['CEP_INI'], data_standard['CEP_FIN'])]

# %%
data_standard_list = data_standard['CEP_RANGE'].explode().tolist()

# %%
data_standard_list[1]
# Out:
# 16800001

# %%
data_standard_list_str = list(map(str, data_standard_list))

# %%
data_shipments_list = data_shipments['CEP'].explode().tolist()

# %%
data_shipments_list[1]
# Out:
# '00005820'

# %%
data_shipments_list_set = set(data_shipments_list)

# %%
len(data_shipments_list_set)
# Out:
# 11070

# %%
data_standard_list_str_set = set(data_standard_list_str)

# %%
len(data_standard_list_str_set)
# Out:
# 51769460

# %%
conta = 0
for valor in data_shipments_list_set:
    if valor in data_standard_list_str_set:
        conta += 1

# %%
porcentagem = round((conta / len(data_shipments_list_set)) * 100, 2)

# %%
porcentagem
# Out:
# 68.52

# %%
print(f'A estimativa de CEPS Shipments dentro do CEPS Standard é de {porcentagem}%')
# Out:
# A estimativa de CEPS Shipments dentro do CEPS Standard é de 68.52%
